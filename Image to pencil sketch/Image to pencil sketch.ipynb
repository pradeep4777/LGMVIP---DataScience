# %% [markdown]
# __Lets Grow More (LGMVIP) - Data Science__
#
# __Task 1 - Image to pencil sketch with python__

# %% [markdown]
# __LGMVIP - March23__

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %%
original_img=cv2.imread(r"C:\Users\prade\PycharmProjects\Data-Science\flower.JPG")

# %%
original_img=cv2.cvtColor(original_img,cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(original_img))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1500>

# %% [markdown]
# __Converting to GrayScale Image__

# %%
gray_image=cv2.cvtColor(original_img,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=1000x1500>

# %% [markdown]
# __Inverting GrayScale Image__

# %%
inv_gray_image=255-gray_image
display(Image.fromarray(inv_gray_image))
# Out:
# <PIL.Image.Image image mode=L size=1000x1500>

# %% [markdown]
# __Bluring Image__

# %%
blur_image=cv2.GaussianBlur(inv_gray_image,(35,35),0)

# %%
display(Image.fromarray(blur_image))
# Out:
# <PIL.Image.Image image mode=L size=1000x1500>

# %% [markdown]
# __inverting blurred image__

# %%
inverted_blur_image=255-blur_image

# %% [markdown]
# __creating pencil sketch image__

# %%
pencil_sketch=cv2.divide(gray_image,inverted_blur_image, scale=256.0)

# %%
cv2.imwrite("pencil_sketch.png",pencil_sketch)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=1000x1500>
